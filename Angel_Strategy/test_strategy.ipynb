# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize
import json
# from smartapi import SmartConnect  # or from smartapi.smartConnect import SmartConnect
from pprint import pprint
from datetime import date,datetime,timedelta
from dateutil.relativedelta import relativedelta, TH
from pprint import pprint
from time import sleep


# url = 'https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json'

# r = requests.get(url)
# # r.json()

# data = r.json()

# %%
import angel_common_functions as f

# %%
# API_KEY="tGA5Z6GH"
# CLIENT_ID="G53356"
# PASSWORD="victor3"

# obj = SmartConnect(api_key=API_KEY)

# data = obj.generateSession(CLIENT_ID, PASSWORD)

# refreshToken = data['data']['refreshToken']

# feedToken = obj.getfeedToken()

# %%
obj = f.angel_login()

# %%
pos=obj.position()['data']

# %%
total_pnl=0
for p in pos:
    pprint(p['tradingsymbol'] + " : " + str(p['pnl']))
    total_pnl += float(p['pnl'])
    
print(total_pnl)
# Out:
# 'NIFTY08JUL2115900CE : 4167.00'
# 'NIFTY08JUL2115850CE : 5976.00'
# 'NIFTY08JUL2115900PE : -3699.00'
# 'NIFTY08JUL2115300PE : 0.00'
# 'NIFTY08JUL2115200PE : -45.00'
# 'NIFTY08JUL2115800PE : 1836.00'
# 'NIFTY08JUL2116300CE : -198.00'
# 'NIFTY08JUL2116200CE : 135.00'
# 8172.0

# %%
o_p_1 = f.generate_order_param('NIFTY08JUL2115700PE','39490','BUY','NFO','75')

# %%
o_p_1
# Out:
# {'variety': 'NORMAL',
#  'tradingsymbol': 'NIFTY08JUL2115700PE',
#  'symboltoken': '39490',
#  'transactiontype': 'BUY',
#  'exchange': 'NFO',
#  'ordertype': 'MARKET',
#  'producttype': 'INTRADAY',
#  'duration': 'DAY',
#  'price': '0',
#  'squareoff': '0',
#  'stoploss': '0',
#  'quantity': '75'}

# %%
ltp_data = f.get_ltp(obj, 'NFO', 'NIFTY08JUL2116500CE', '45003')

# %%
ltp_data
# Out:
# 0.75

# %%
order_data = obj.placeOrder(o_p_1)

# %%
order_data = f.place_Order(obj, o_p_1)

# %%
order_data
# Out:
# {'message': 'Failed to get symbol details',
#  'errorcode': 'AB1018',
#  'status': False,
#  'data': None}

# %%
order_book=obj.orderBook()['data']
# for o in order_book:
#     if o['orderid']=='210707000644304':
#         print(o)

# %%
# order_df = pd.DataFrame(order_book)
order_df.loc[order_df['tradingsymbol'] == 'NIFTY08JUL2116200CE']

# %%
 import xlwings as xl
wb = xl.Book("Algo_excel.xlsm")
sht = wb.sheets['CONFIG']

sht['A50'].value = str(ord_book['data'])

# %%
rms = obj.rmsLimit()
rms
# Out:
# {'status': True,
#  'message': 'SUCCESS',
#  'errorcode': '',
#  'data': {'net': '558409.31542900006752',
#   'availablecash': '558409.31542900006752',
#   'availableintradaypayin': '0',
#   'availablelimitmargin': '0',
#   'collateral': '127121.83400000000256',
#   'm2munrealized': '-31.607143000000000654',
#   'm2mrealized': '3736.6071430000001783',
#   'utiliseddebits': '138.27857099999999946',
#   'utilisedspan': '0',
#   'utilisedoptionpremium': '0',
#   'utilisedholdingsales': '0',
#   'utilisedexposure': '0',
#   'utilisedturnover': '0',
#   'utilisedpayout': '0'}}

# %%
# for i in range(1,100):
rms = obj.rmsLimit()
pnl = float(rms['data']['m2munrealized']) + float(rms['data']['m2mrealized'])
print(pnl)
#     sleep(1)
# Out:
# 742.5

# %%
#pos = obj.position()['data']
pnl = 0
for p in pos:
    pnl = pnl+float(p['realised']) + float(p['unrealised'])
#     print(p['pnl'] + " : " + p['realised'] + "  :  " + p['unrealised'])
    
print(str(pnl))
# Out:
# 8172.0

# %%
print('buy_qty' + " : " + 'sell_qty' + " : " + 'net_qty' + " : " + 'pnl' + " : " + 'realised' + " : " + 'unrealised')
for p in pos:
    if p['instrumenttype'] == "OPTIDX":
        symbol = p['tradingsymbol']
        symbol_token = p['symboltoken']
        exch = p['exchange']
        buy_qty = p['buyqty']
        sell_qty = p['sellqty']
        net_qty = p['netqty']
        pnl = p['pnl']
        realised = p['realised']
        unrealised = p['unrealised']
        print(buy_qty + " : " + sell_qty + " : " + net_qty + " : " + pnl + " : " + realised + " : " + unrealised)
# Out:
# buy_qty : sell_qty : net_qty : pnl : realised : unrealised
# 900 : 900 : 0 : 4167.00 : 4167.00 : 0.00
# 900 : 900 : 0 : 5976.00 : 5976.00 : 0.00
# 1350 : 1350 : 0 : -3699.00 : -3699.00 : -0.00
# 450 : 450 : 0 : 0.00 : 0.00 : 0.00
# 450 : 450 : 0 : -45.00 : -45.00 : 0.00
# 450 : 450 : 0 : 1836.00 : 1836.00 : -0.00
# 900 : 900 : 0 : -198.00 : -198.00 : 0.00
# 450 : 450 : 0 : 135.00 : 135.00 : 0.00

# %%
pos
# Out:
# [{'symboltoken': '39504',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115900CE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15900.0',
#   'optiontype': 'CE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '39.65',
#   'sellavgprice': '44.28',
#   'avgnetprice': '0.00',
#   'netvalue': '4162.50',
#   'netqty': '0',
#   'totalbuyvalue': '35685.00',
#   'totalsellvalue': '39847.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '39.65',
#   'totalsellavgprice': '44.28',
#   'netprice': '0.00',
#   'buyqty': '900',
#   'sellqty': '900',
#   'buyamount': '35685.00',
#   'sellamount': '39847.50',
#   'pnl': '4167.00',
#   'realised': '4167.00',
#   'unrealised': '0.00',
#   'ltp': '16.75',
#   'close': '31.05'},
#  {'symboltoken': '39502',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115850CE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15850.0',
#   'optiontype': 'CE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '70.98',
#   'sellavgprice': '77.62',
#   'avgnetprice': '0.00',
#   'netvalue': '5977.50',
#   'netqty': '0',
#   'totalbuyvalue': '63885.00',
#   'totalsellvalue': '69862.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '70.98',
#   'totalsellavgprice': '77.62',
#   'netprice': '0.00',
#   'buyqty': '900',
#   'sellqty': '900',
#   'buyamount': '63885.00',
#   'sellamount': '69862.50',
#   'pnl': '5976.00',
#   'realised': '5976.00',
#   'unrealised': '0.00',
#   'ltp': '32.8',
#   'close': '52.3'},
#  {'symboltoken': '39505',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115900PE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15900.0',
#   'optiontype': 'PE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '61.17',
#   'sellavgprice': '58.43',
#   'avgnetprice': '0.00',
#   'netvalue': '-3690.00',
#   'netqty': '0',
#   'totalbuyvalue': '82575.00',
#   'totalsellvalue': '78885.00',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '61.17',
#   'totalsellavgprice': '58.43',
#   'netprice': '0.00',
#   'buyqty': '1350',
#   'sellqty': '1350',
#   'buyamount': '82575.00',
#   'sellamount': '78885.00',
#   'pnl': '-3699.00',
#   'realised': '-3699.00',
#   'unrealised': '-0.00',
#   'ltp': '103.0',
#   'close': '96.95'},
#  {'symboltoken': '39464',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115300PE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15300.0',
#   'optiontype': 'PE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '2.85',
#   'sellavgprice': '2.85',
#   'avgnetprice': '0.00',
#   'netvalue': '0.00',
#   'netqty': '0',
#   'totalbuyvalue': '1282.50',
#   'totalsellvalue': '1282.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '2.85',
#   'totalsellavgprice': '2.85',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '1282.50',
#   'sellamount': '1282.50',
#   'pnl': '0.00',
#   'realised': '0.00',
#   'unrealised': '0.00',
#   'ltp': '2.0',
#   'close': '2.9'},
#  {'symboltoken': '39460',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115200PE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15200.0',
#   'optiontype': 'PE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '2.35',
#   'sellavgprice': '2.25',
#   'avgnetprice': '0.00',
#   'netvalue': '-45.00',
#   'netqty': '0',
#   'totalbuyvalue': '1057.50',
#   'totalsellvalue': '1012.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '2.35',
#   'totalsellavgprice': '2.25',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '1057.50',
#   'sellamount': '1012.50',
#   'pnl': '-45.00',
#   'realised': '-45.00',
#   'unrealised': '0.00',
#   'ltp': '1.35',
#   'close': '2.25'},
#  {'symboltoken': '39501',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115800PE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15800.0',
#   'optiontype': 'PE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '34.10',
#   'sellavgprice': '38.18',
#   'avgnetprice': '0.00',
#   'netvalue': '1833.75',
#   'netqty': '0',
#   'totalbuyvalue': '15345.00',
#   'totalsellvalue': '17178.75',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '34.10',
#   'totalsellavgprice': '38.18',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '15345.00',
#   'sellamount': '17178.75',
#   'pnl': '1836.00',
#   'realised': '1836.00',
#   'unrealised': '-0.00',
#   'ltp': '43.5',
#   'close': '45.65'},
#  {'symboltoken': '36200',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2116300CE',
#   'symbolgroup': 'XX',
#   'strikeprice': '16300.0',
#   'optiontype': 'CE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '1.50',
#   'sellavgprice': '1.28',
#   'avgnetprice': '0.00',
#   'netvalue': '-202.50',
#   'netqty': '0',
#   'totalbuyvalue': '1350.00',
#   'totalsellvalue': '1147.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '1.50',
#   'totalsellavgprice': '1.28',
#   'netprice': '0.00',
#   'buyqty': '900',
#   'sellqty': '900',
#   'buyamount': '1350.00',
#   'sellamount': '1147.50',
#   'pnl': '-198.00',
#   'realised': '-198.00',
#   'unrealised': '0.00',
#   'ltp': '1.15',
#   'close': '1.25'},
#  {'symboltoken': '39536',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2116200CE',
#   'symbolgroup': 'XX',
#   'strikeprice': '16200.0',
#   'optiontype': 'CE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '1.70',
#   'sellavgprice': '2.00',
#   'avgnetprice': '0.00',
#   'netvalue': '135.00',
#   'netqty': '0',
#   'totalbuyvalue': '765.00',
#   'totalsellvalue': '900.00',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '1.70',
#   'totalsellavgprice': '2.00',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '765.00',
#   'sellamount': '900.00',
#   'pnl': '135.00',
#   'realised': '135.00',
#   'unrealised': '0.00',
#   'ltp': '1.4',
#   'close': '1.8'}]

# %%
pos #open position 16200CE
# Out:
# [{'symboltoken': '39498',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115800CE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15800.0',
#   'optiontype': 'CE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '47.80',
#   'sellavgprice': '64.33',
#   'avgnetprice': '0.00',
#   'netvalue': '7440.00',
#   'netqty': '0',
#   'totalbuyvalue': '21510.00',
#   'totalsellvalue': '28950.00',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '47.80',
#   'totalsellavgprice': '64.33',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '21510.00',
#   'sellamount': '28950.00',
#   'pnl': '7438.50',
#   'realised': '7438.50',
#   'unrealised': '-0.00',
#   'ltp': '67.25',
#   'close': '62.05'},
#  {'symboltoken': '39460',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115200PE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15200.0',
#   'optiontype': 'PE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '2.02',
#   'sellavgprice': '1.85',
#   'avgnetprice': '0.00',
#   'netvalue': '-78.75',
#   'netqty': '0',
#   'totalbuyvalue': '911.25',
#   'totalsellvalue': '832.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '2.02',
#   'totalsellavgprice': '1.85',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '911.25',
#   'sellamount': '832.50',
#   'pnl': '-76.50',
#   'realised': '-76.50',
#   'unrealised': '-0.00',
#   'ltp': '1.9',
#   'close': '1.75'},
#  {'symboltoken': '39501',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115800PE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15800.0',
#   'optiontype': 'PE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '46.68',
#   'sellavgprice': '38.65',
#   'avgnetprice': '0.00',
#   'netvalue': '-3611.25',
#   'netqty': '0',
#   'totalbuyvalue': '21003.75',
#   'totalsellvalue': '17392.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '46.68',
#   'totalsellavgprice': '38.65',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '21003.75',
#   'sellamount': '17392.50',
#   'pnl': '-3613.50',
#   'realised': '-3613.50',
#   'unrealised': '0.00',
#   'ltp': '31.55',
#   'close': '42.85'},
#  {'symboltoken': '39536',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2116200CE',
#   'symbolgroup': 'XX',
#   'strikeprice': '16200.0',
#   'optiontype': 'CE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '1.87',
#   'sellavgprice': '1.35',
#   'avgnetprice': '5.00',
#   'netvalue': '-375.00',
#   'netqty': '75',
#   'totalbuyvalue': '982.50',
#   'totalsellvalue': '607.50',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '1.87',
#   'totalsellavgprice': '1.35',
#   'netprice': '5.00',
#   'buyqty': '525',
#   'sellqty': '450',
#   'buyamount': '982.50',
#   'sellamount': '607.50',
#   'pnl': '-265.50',
#   'realised': '-234.00',
#   'unrealised': '-31.50',
#   'ltp': '1.45',
#   'close': '1.9'},
#  {'symboltoken': '39496',
#   'symbolname': 'NIFTY',
#   'instrumenttype': 'OPTIDX',
#   'priceden': '1.00',
#   'pricenum': '1.00',
#   'genden': '1.00',
#   'gennum': '1.00',
#   'precision': '2',
#   'multiplier': '-1',
#   'boardlotsize': '1',
#   'exchange': 'NFO',
#   'producttype': 'INTRADAY',
#   'tradingsymbol': 'NIFTY08JUL2115750PE',
#   'symbolgroup': 'XX',
#   'strikeprice': '15750.0',
#   'optiontype': 'PE',
#   'expirydate': '08JUL2021',
#   'lotsize': '75',
#   'cfbuyqty': '0',
#   'cfsellqty': '0',
#   'cfbuyamount': '0.00',
#   'cfsellamount': '0.00',
#   'buyavgprice': '26.40',
#   'sellavgprice': '26.89',
#   'avgnetprice': '0.00',
#   'netvalue': '221.25',
#   'netqty': '0',
#   'totalbuyvalue': '11880.00',
#   'totalsellvalue': '12101.25',
#   'cfbuyavgprice': '0.00',
#   'cfsellavgprice': '0.00',
#   'totalbuyavgprice': '26.40',
#   'totalsellavgprice': '26.89',
#   'netprice': '0.00',
#   'buyqty': '450',
#   'sellqty': '450',
#   'buyamount': '11880.00',
#   'sellamount': '12101.25',
#   'pnl': '220.50',
#   'realised': '220.50',
#   'unrealised': '0.00',
#   'ltp': '18.1',
#   'close': '26.85'}]

# %%
pos #all close positions

# %%
order_book = obj.orderBook()['data']
cnt=0
for o in order_book:
    if o['status'] == 'complete':
        cnt += 1

order_book
# Out:
# [{'variety': 'NORMAL',
#   'ordertype': 'MARKET',
#   'producttype': 'INTRADAY',
#   'duration': 'DAY',
#   'price': 0.0,
#   'triggerprice': 0.0,
#   'quantity': '50',
#   'disclosedquantity': '0',
#   'squareoff': 0.0,
#   'stoploss': 0.0,
#   'trailingstoploss': 0.0,
#   'tradingsymbol': 'NIFTY05AUG2115700PE',
#   'transactiontype': 'SELL',
#   'exchange': 'NFO',
#   'symboltoken': '39604',
#   'ordertag': '',
#   'instrumenttype': 'OPTIDX',
#   'strikeprice': 15700.0,
#   'optiontype': 'PE',
#   'expirydate': '05AUG2021',
#   'lotsize': '50',
#   'cancelsize': '0',
#   'averageprice': 0.0,
#   'filledshares': '0',
#   'unfilledshares': '50',
#   'orderid': '210710000004380',
#   'text': 'Trading is not allowed in the selected contract due to low liquidity.',
#   'status': 'rejected',
#   'orderstatus': 'rejected',
#   'updatetime': '10-Jul-2021 15:45:48',
#   'exchtime': '',
#   'exchorderupdatetime': '',
#   'fillid': '',
#   'filltime': '',
#   'parentorderid': ''},
#  {'variety': 'NORMAL',
#   'ordertype': 'MARKET',
#   'producttype': 'INTRADAY',
#   'duration': 'DAY',
#   'price': 0.0,
#   'triggerprice': 0.0,
#   'quantity': '50',
#   'disclosedquantity': '0',
#   'squareoff': 0.0,
#   'stoploss': 0.0,
#   'trailingstoploss': 0.0,
#   'tradingsymbol': 'NIFTY05AUG2115700PE',
#   'transactiontype': 'SELL',
#   'exchange': 'NFO',
#   'symboltoken': '39604',
#   'ordertag': '',
#   'instrumenttype': 'OPTIDX',
#   'strikeprice': 15700.0,
#   'optiontype': 'PE',
#   'expirydate': '05AUG2021',
#   'lotsize': '50',
#   'cancelsize': '0',
#   'averageprice': 0.0,
#   'filledshares': '0',
#   'unfilledshares': '50',
#   'orderid': '210710000004244',
#   'text': 'Trading is not allowed in the selected contract due to low liquidity.',
#   'status': 'rejected',
#   'orderstatus': 'rejected',
#   'updatetime': '10-Jul-2021 15:20:20',
#   'exchtime': '',
#   'exchorderupdatetime': '',
#   'fillid': '',
#   'filltime': '',
#   'parentorderid': ''}]
